// %% [markdown]
// #### Parallele und funktionale Programmierung
// ### Übungsblatt 11
// ---

// %% [markdown]
// ## <u>Bonus</u>aufgabe 11.5: Listenfunktionen
// Implementieren Sie die folgenden Listenfunktionen in der Datei "ListFunctions.scala":

// %% [markdown]
// **a)** `find[E]: (List[E], E) => List[Int]`: Die Funktion `find(ls, e)` soll die Liste aller Indizes (beginnend bei 0) zurückgeben, an denen das Element `e` in der Liste `ls` vorkommt.

// %%
def find[E]: (List[E], E) => List[Int] = ??? // TODO

// %%
// Kleiner Testfall zu dieser Teilaufgabe:
{def f0[E]: (List[E], E) => List[Int] = find}
assert (find(List('P', 'F', 'P'), 'P') == List(0, 2)); print("✅")

// %% [markdown]
// **b)** `powerSet[E]: List[E] => List[List[E]]`: Die Funktion `powerSet(ls)` soll die Potenzmenge von `ls` als Liste zurückgeben. Die Reihenfolge der Elemente in den Ergebnislisten ist unerheblich.

// %%
def powerSet[E]: List[E] => List[List[E]] = ??? // TODO

// %%
// Kleiner Testfall zu dieser Teilaufgabe:
{def f1[E]: List[E] => List[List[E]] = powerSet}
assert (powerSet(List('A', 'B')).map(_.sorted).sortBy(_.foldLeft(0)(_*10+_-'A'+1)) == List(Nil, List('A'), List('B'), List('A', 'B'))); print("✅")

// %% [markdown]
// **Hinweis:** Versuchen Sie als Vorbereitung auf die Klausur, in obigen Funktionen möglichst viele Methoden der Klasse `List` (z.B. `map`, `flatMap`, `filter`, ...) zu verwenden.
