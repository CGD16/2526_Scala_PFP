// %% [markdown]
// #### Parallele und funktionale Programmierung
// ### Übungsblatt 10
// ---

// %% [markdown]
// ## <u>Bonus</u>aufgabe 10.7: Counting Sort
// Das Counting-Sort-Verfahren ist ein Sortierverfahren für Zahlenlisten. Der Algorithmus zählt, wie häufig jedes Element in einer Eingabeliste vorkommt, und erzeugt anschließend entsprechend viele Elemente in der Ergebnisliste, beginnend beim kleinsten Element. Setzen Sie dieses Verfahren schrittweise mittels der nachfolgend genannten Funktionen in der Datei `CountingSort` um. Verwenden Sie zur Lösung nur Rekursion, Mustervergleich, arithmetische Operationen, Konstruktoren der Klasse `List` sowie `::`. Alle anderen Methoden (auch der Klasse `List`) sind in dieser Aufgabe **verboten**.
// **Hinweis:** Sie können annehmen, dass die zu sortierende Liste nur nicht-negative Zahlen enthält.

// %% [markdown]
// **a)** `incCount: (Int, List[Int]) => List[Int]`: Die Funktion `incCount(i, cs)` erhöht in der Liste der Häufigkeiten `cs` den Eintrag an der Stelle `i` um eins. Existiert der Eintrag noch nicht, wird dieser angelegt.
//
// **Beispiele:**
// `incCount(0, Nil) == List(1)`
// `incCount(2, List(0, 1)) == List(0, 1, 1)`
// `incCount(1, List(0, 1, 1)) == List(0, 2, 1)`

// %%
def incCount: (Int, List[Int]) => List[Int] = ??? // TODO

// %%
// Kleiner Testfall zu dieser Teilaufgabe:
{val f: (Int, List[Int]) => List[Int] = incCount}
assert(incCount(0, Nil) == List(1)); print("✅")
assert(incCount(2, List(0, 1)) == List(0, 1, 1)); print("✅")
assert(incCount(1, List(0, 1, 1)) == List(0, 2, 1)); print("✅")

// %% [markdown]
// **b)** `getCounts: List[Int] => List[Int]`: Die Funktion `getCounts(ls)` gibt eine Liste der Häufigkeiten aller Elemente aus `ls` zurück. Verwenden Sie zur Lösung die Funktion `incCount` aus der vorherigen Teilaufgabe.
//
// **Beispiel:** `getCounts(List(1, 2, 1)) == List(0, 2, 1)`

// %%
def getCounts: List[Int] => List[Int] = ??? // TODO

// %%
// Kleiner Testfall zu dieser Teilaufgabe:
{val f: List[Int] => List[Int] = getCounts}
assert(getCounts(List(1, 2, 1)) == List(0, 2, 1)); print("✅")

// %% [markdown]
// **c)** `countingSort: List[Int] => List[Int]`: Die Funktion `countingSort(ls)` ermittelt zunächst die Häufigkeiten aller Elemente (mittels `getCounts`) und erzeugt dann die entsprechende Anzahl an Elementen als Ausgabeliste.
//
// **Beispiel:** `countingSort(List(1,2,1,7,4,7)) == List(1,1,2,4,7,7)`
// **Hinweis:** Sie können zur Vereinfachung Hilfsfunktionen definieren.

// %%
def countingSort: List[Int] => List[Int] = ??? // TODO

// %%
// Kleiner Testfall zu dieser Teilaufgabe:
{val f: List[Int] => List[Int] = countingSort}
assert(countingSort(List(1, 2, 1, 7, 4, 7)) == List(1, 1, 2, 4, 7, 7)); print("✅")
