// %% [markdown]
// # Aufgabe 5 (Scala: Ameise)

// %% [markdown]
// _Verwenden Sie ausschließlich aus der Lehrveranstaltung bekannte Scala-Konstrukte, dabei sind `var` und seiteneffektbehaftete Methoden/Klassen/Objekte strikt untersagt._

// %% [markdown]
// Langtons Ameise lebt auf einem unendlich großen Raster aus anfangs weißen, viereckigen Feldern. In jedem Zeitschritt tut sie Folgendes in genau dieser Reihenfolge:
//
// 1. Steht sie auf einem weißen Feld, dreht sie sich um 90° im Uhrzeigersinn, ansonsten gegen den Uhrzeigersinn.
// 2. Sie ändert die Farbe ihres aktuellen Feldes: Weiße Felder werden schwarz und schwarze weiß.
// 3. Sie läuft auf das nächste Feld in Blickrichtung.

// %% [markdown]
// <img src="lib/2022_02_22_klausur_p10_Langton.png" title="Tree Example for LCA" style="height: 150px;"/>

// %% [markdown]
// Ziel dieser Aufgabe ist es, Ameise und Raster zu simulieren. Dazu seien die folgenden Definitionen vorgegeben:

// %%
case class Ant(x : Int, y : Int, dir : Int)
// dir 0/1/2/3 entspricht Norden/Osten/Sueden/Westen
case class Tile (x : Int, y : Int, black : Boolean) // Ein Feld
type Trail = List[Tile] // Genau alle besuchten Felder; jedes Feld nur einmal
type State = (Ant, Trail) // Der Gesamtzustand

// Aenderung von x und y pro Schritt fuer jede der vier Blickrichtungen
val stepDelta = List((0,1), (1,0), (0,-1), (-1, 0))

// Liefert die Blickrichtung, die die Ameise als naechstes annimmt
def newDir : State => Int = //...
   /*...*/ s => (s._1.dir + (if (getColor((s._1.x,s._1.y),s)) 3 else 1)) % 4

// Liefert die Farbe an den gegebenen Koordinaten
def getColor : ((Int, Int),State) => Boolean = //...
   /*...*/ {case ((x,y),s) if s._2.find(t => t.x == x && t.y == y) == None => false
   /*...*/  case ((x,y),s) => s._2.find(t => t.x == x && t.y == y).get.black       }

// %% [markdown]
// **a)** Ergänzen Sie die Funktion `updateColor`, die das `Tile` an der Stelle `(x,y)` in der Farbe `b` einfärbt. Achten Sie darauf, dass sich jede Koordinate nur einmal in einem `Trail` befinden darf.

// %%
def updateColor :((Int, Int), Boolean, State) => State = {
   case ((x, y), b , (ant, trl)) =>
      ( /*** IHR CODE HIER ***/ )}

// %%
// Beispiel und Schnelltest:
{
def check: State => State => Boolean = expected => actual => (expected,actual) match {
   case ((expectedAnt,expectedTrail),(actualAnt,actualTrail)) =>
      expectedAnt == actualAnt &&
      expectedTrail.length == actualTrail.length &&
      (for(t@Tile(x,y,b) <- expectedTrail) yield actualTrail.contains(t) && !actualTrail.contains(Tile(x,y,!b))).forall(w=>w) &&
      (for(t@Tile(x,y,b) <- actualTrail) yield expectedTrail.contains(t) && !expectedTrail.contains(Tile(x,y,!b))).forall(w=>w)
}

assert(check(Ant(42,42,0),List(Tile(5,7,true))) (updateColor((5,7),true,(Ant(42,42,0),Nil)))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),Nil)))); print("✅")
print("|")
assert(check(Ant(42,42,0),List(Tile(5,7,true))) (updateColor((5,7),true,(Ant(42,42,0),List(Tile(5,7,true)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,7,true))) (updateColor((5,7),true,(Ant(42,42,0),List(Tile(5,7,false)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),List(Tile(5,7,true)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),List(Tile(5,7,false)))))); print("✅")
print("|")
assert(check(Ant(42,42,0),List(Tile(5,7,true),Tile(6,7,true))) (updateColor((5,7),true,(Ant(42,42,0),List(Tile(6,7,true)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,7,true),Tile(6,7,false))) (updateColor((5,7),true,(Ant(42,42,0),List(Tile(6,7,false)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(6,7,true),Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),List(Tile(6,7,true)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(6,7,false),Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),List(Tile(6,7,false)))))); print("✅")
print("|")
assert(check(Ant(42,42,0),List(Tile(5,7,true),Tile(5,6,true))) (updateColor((5,7),true,(Ant(42,42,0),List(Tile(5,6,true)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,7,true),Tile(5,6,false))) (updateColor((5,7),true,(Ant(42,42,0),List(Tile(5,6,false)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,6,true),Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),List(Tile(5,6,true)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,6,false),Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),List(Tile(5,6,false)))))); print("✅")
print("|")
assert(check(Ant(42,42,0),List(Tile(5,7,true),Tile(6,7,true))) (updateColor((5,7),true,(Ant(42,42,0),List(Tile(5,7,true),Tile(6,7,true)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(5,7,true),Tile(6,7,false))) (updateColor((5,7),true,(Ant(42,42,0),List(Tile(5,7,false),Tile(6,7,false)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(6,7,true),Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),List(Tile(6,7,true),Tile(5,7,true)))))); print("✅")
assert(check(Ant(42,42,0),List(Tile(6,7,false),Tile(5,7,false))) (updateColor((5,7),false,(Ant(42,42,0),List(Tile(6,7,false),Tile(5,7,false)))))); print("✅")
}

// %% [markdown]
// **b)** Ergänzen Sie nun die Funktion `updateAnt`, die die Ameise auf das gegebene Feld `(x,y)` mit Richtung `dir` setzt. Sollte das Feld noch nicht existieren, muss es erstellt werden.

// %%
def updateAnt : ((Int, Int, Int), State ) => State = {
   case ((x, y, dir), (ant, trl)) =>
      ( /*** IHR CODE HIER ***/ ,
         if( /*** IHR CODE HIER ***/ ) /*** IHR CODE HIER ***/
         else /*** IHR CODE HIER ***/ )}

// %%
// Beispiel und Schnelltest:
{
def check: State => State => Boolean = expected => actual => (expected,actual) match {
   case ((expectedAnt,expectedTrail),(actualAnt,actualTrail)) =>
      expectedAnt == actualAnt &&
      expectedTrail.length == actualTrail.length &&
      (for(t@Tile(x,y,b) <- expectedTrail) yield actualTrail.contains(t) && !actualTrail.contains(Tile(x,y,!b))).forall(w=>w) &&
      (for(t@Tile(x,y,b) <- actualTrail) yield expectedTrail.contains(t) && !expectedTrail.contains(Tile(x,y,!b))).forall(w=>w)
}

assert(check(Ant(5,7,0),List(Tile(5,7,false))) (updateAnt((5,7,0),(Ant(42,42,42),Nil)))); print("✅")
print("|")
assert(check(Ant(5,7,0),List(Tile(5,7,true))) (updateAnt((5,7,0),(Ant(42,42,42),List(Tile(5,7,true)))))); print("✅")
assert(check(Ant(5,7,0),List(Tile(5,7,false))) (updateAnt((5,7,0),(Ant(42,42,42),List(Tile(5,7,false)))))); print("✅")
print("|")
assert(check(Ant(5,7,0),List(Tile(5,7,false),Tile(6,7,true))) (updateAnt((5,7,0),(Ant(42,42,42),List(Tile(6,7,true)))))); print("✅")
assert(check(Ant(5,7,0),List(Tile(5,6,false),Tile(5,7,false))) (updateAnt((5,7,0),(Ant(42,42,42),List(Tile(5,6,false)))))); print("✅")
print("|")
assert(check(Ant(5,7,0),List(Tile(5,7,true),Tile(5,6,true))) (updateAnt((5,7,0),(Ant(42,42,42),List(Tile(5,6,true),Tile(5,7,true)))))); print("✅")
assert(check(Ant(5,7,0),List(Tile(5,7,false),Tile(5,6,true))) (updateAnt((5,7,0),(Ant(42,42,42),List(Tile(5,6,true),Tile(5,7,false)))))); print("✅")
assert(check(Ant(5,7,0),List(Tile(5,6,true),Tile(5,7,true))) (updateAnt((5,7,0),(Ant(42,42,42),List(Tile(5,7,true),Tile(5,6,true)))))); print("✅")
assert(check(Ant(5,7,0),List(Tile(5,6,true),Tile(5,7,false))) (updateAnt((5,7,0),(Ant(42,42,42),List(Tile(5,7,false),Tile(5,6,true)))))); print("✅")
}

// %% [markdown]
// **c)** Vervollständigen Sie die Funktion `step`. Sie erhält einen Zustand `s` und gibt den Folgezustand nach einem Zeitschritt zurück.

// %%
def step : State => State = s => {
   val (ant, trl) = s; val nd = newDir(s);
   /*** IHR CODE HIER ***/
}

// %%
// Beispiel und Schnelltest:
{
def check: State => State => Boolean = expected => actual => (expected,actual) match {
   case ((expectedAnt,expectedTrail),(actualAnt,actualTrail)) =>
      expectedAnt == actualAnt &&
      expectedTrail.length == actualTrail.length &&
      (for(t@Tile(x,y,b) <- expectedTrail) yield actualTrail.contains(t) && !actualTrail.contains(Tile(x,y,!b))).forall(w=>w) &&
      (for(t@Tile(x,y,b) <- actualTrail) yield expectedTrail.contains(t) && !expectedTrail.contains(Tile(x,y,!b))).forall(w=>w)
}

assert(check(Ant(6,7,1),List(Tile(6,7,false),Tile(5,7,true))) (step(Ant(5,7,0),Nil))); print("✅")
assert(check(Ant(5,6,2),List(Tile(5,6,false),Tile(5,7,true))) (step(Ant(5,7,1),Nil))); print("✅")
assert(check(Ant(4,7,3),List(Tile(4,7,false),Tile(5,7,true))) (step(Ant(5,7,2),Nil))); print("✅")
assert(check(Ant(5,8,0),List(Tile(5,8,false),Tile(5,7,true))) (step(Ant(5,7,3),Nil))); print("✅")
print("|")
assert(check(Ant(6,7,1),List(Tile(6,7,false),Tile(5,7,true))) (step(Ant(5,7,0),List(Tile(5,7,false))))); print("✅")
assert(check(Ant(5,6,2),List(Tile(5,6,false),Tile(5,7,true))) (step(Ant(5,7,1),List(Tile(5,7,false))))); print("✅")
assert(check(Ant(4,7,3),List(Tile(4,7,false),Tile(5,7,true))) (step(Ant(5,7,2),List(Tile(5,7,false))))); print("✅")
assert(check(Ant(5,8,0),List(Tile(5,8,false),Tile(5,7,true))) (step(Ant(5,7,3),List(Tile(5,7,false))))); print("✅")
print("|")
assert(check(Ant(4,7,3),List(Tile(4,7,false),Tile(5,7,false))) (step(Ant(5,7,0),List(Tile(5,7,true))))); print("✅")
assert(check(Ant(5,8,0),List(Tile(5,8,false),Tile(5,7,false))) (step(Ant(5,7,1),List(Tile(5,7,true))))); print("✅")
assert(check(Ant(6,7,1),List(Tile(6,7,false),Tile(5,7,false))) (step(Ant(5,7,2),List(Tile(5,7,true))))); print("✅")
assert(check(Ant(5,6,2),List(Tile(5,6,false),Tile(5,7,false))) (step(Ant(5,7,3),List(Tile(5,7,true))))); print("✅")
print("|")
assert(check(Ant(6,7,1),List(Tile(6,7,true),Tile(5,7,true))) (step(Ant(5,7,0),List(Tile(6,7,true),Tile(5,7,false))))); print("✅")
assert(check(Ant(5,6,2),List(Tile(5,6,true),Tile(5,7,true))) (step(Ant(5,7,1),List(Tile(5,6,true),Tile(5,7,false))))); print("✅")
assert(check(Ant(4,7,3),List(Tile(4,7,true),Tile(5,7,true))) (step(Ant(5,7,2),List(Tile(5,7,false),Tile(4,7,true))))); print("✅")
assert(check(Ant(5,8,0),List(Tile(5,8,true),Tile(5,7,true))) (step(Ant(5,7,3),List(Tile(5,7,false),Tile(5,8,true))))); print("✅")
print("|")
assert(check(Ant(4,7,3),List(Tile(4,7,true),Tile(5,7,false))) (step(Ant(5,7,0),List(Tile(5,7,true),Tile(4,7,true))))); print("✅")
assert(check(Ant(5,8,0),List(Tile(5,8,true),Tile(5,7,false))) (step(Ant(5,7,1),List(Tile(5,7,true),Tile(5,8,true))))); print("✅")
assert(check(Ant(6,7,1),List(Tile(6,7,true),Tile(5,7,false))) (step(Ant(5,7,2),List(Tile(6,7,true),Tile(5,7,true))))); print("✅")
assert(check(Ant(5,6,2),List(Tile(5,6,true),Tile(5,7,false))) (step(Ant(5,7,3),List(Tile(5,6,true),Tile(5,7,true))))); print("✅")
}

// %% [markdown]
// **d)** Schreiben Sie schließlich die Funktion `simulation`, welche für einen gegebenen Startzustand `s` eine unendliche Liste aus `s` sowie allen seinen Folgezuständen zurückliefert.

// %%
def simulation : State => LazyList[State] = s =>
    /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
{
def check: State => State => Boolean = expected => actual => (expected,actual) match {
   case ((expectedAnt,expectedTrail),(actualAnt,actualTrail)) =>
      expectedAnt == actualAnt &&
      expectedTrail.length == actualTrail.length &&
      (for(t@Tile(x,y,b) <- expectedTrail) yield actualTrail.contains(t) && !actualTrail.contains(Tile(x,y,!b))).forall(w=>w) &&
      (for(t@Tile(x,y,b) <- actualTrail) yield expectedTrail.contains(t) && !expectedTrail.contains(Tile(x,y,!b))).forall(w=>w)
}

assert(check(Ant(5,7,0),Nil) (simulation(Ant(5,7,0),Nil).head)); print("✅")
assert(check(Ant(6,7,1),List(Tile(6,7,false),Tile(5,7,true))) (simulation(Ant(5,7,0),Nil).drop(1).head)); print("✅")
assert(check(Ant(6,6,2),List(Tile(6,6,false),Tile(6,7,true),Tile(5,7,true))) (simulation(Ant(5,7,0),Nil).drop(2).head)); print("✅")
assert(check(Ant(5,6,3),List(Tile(5,6,false),Tile(6,6,true),Tile(6,7,true),Tile(5,7,true))) (simulation(Ant(5,7,0),Nil).drop(3).head)); print("✅")
assert(check(Ant(5,7,0),List(Tile(5,6,true),Tile(6,6,true),Tile(6,7,true),Tile(5,7,true))) (simulation(Ant(5,7,0),Nil).drop(4).head)); print("✅")
assert(check(Ant(4,7,3),List(Tile(4,7,false),Tile(5,6,true),Tile(6,6,true),Tile(6,7,true),Tile(5,7,false))) (simulation(Ant(5,7,0),Nil).drop(5).head)); print("✅")
}
