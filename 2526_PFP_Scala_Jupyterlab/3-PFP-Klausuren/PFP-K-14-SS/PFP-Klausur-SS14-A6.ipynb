// %% [markdown]
// # Aufgabe 6 (Scala - Lauflängendekodierung)

// %% [markdown]
// _Verwenden Sie ausschließlich aus der Lehrveranstaltung bekannte Scala-Konstrukte, dabei sind `var` und seiteneffektbehaftete Methoden/Klassen/Objekte strikt untersagt._

// %% [markdown]
// <div class="alert alert-block alert-danger">
// <b>WICHTIG:</b> Die <b>ursprüngliche</b> Klausur hat <b>damals</b> systembedingt <code>Stream</code> (<i>"Strom"</i>) statt <code>LazyList</code> verwendet!<br/>
// Grund für die Abweichung <b>hier</b>: <i>"type Stream in package scala is deprecated since 2.13.0: Use LazyList instead of Stream"</i><br/>
// <b>Ersetzen</b> Sie daher in der Aufgabenstellung die Begriffe <i>"Strom"</i> bzw. "<code>Stream</code>" <b>gedanklich</b> durch die <b>neuere</b> <code>LazyList</code>.
// </div>

// %% [markdown]
// Bei der folgenden Lauflängencodierung wird ein mehrfach aufeinander folgendes Zeichen `c` als Tupel `(c, k)` codiert, wobei `k` die Anzahl der Wiederholungen angibt.
// **Beispiel:** `"aaabbccc..."` wird zu `('a', 3), ('b', 2), ('c', 3), ...`

// %% [markdown]
// **a)** Definieren Sie die Funktion `encodeHead(cs)`, die aus einem Zeichenstrom `cs` mittels Bedarfsauswertung das erste codierte Tupel `t` ermittelt und dieses zusammen mit dem Reststrom `rs` als Tupel `(t, rs)` zurückgibt. Nehmen Sie an, dass `cs` nicht leer ist.
// **Beispiel:** `encodeHead("aaabbccc".toStream) == ((a,3),Stream(b, ?))`
// **Tipps:** Verwenden Sie die Methoden `takeWhile`, `dropWhile` und `length` in `Stream`.

// %%
def encodeHead: LazyList[Char] => ((Char, Int), LazyList[Char]) = cs => {
   val h = cs.head
   /*** IHR CODE HIER ***/
}

// %%
// Beispiel und Schnelltest:
assert(encodeHead(LazyList.from("aaabbccc")) == (('a',3),LazyList.from("bbccc"))); print("✅")
print("|")
assert(encodeHead(LazyList.from("bbccc")) == (('b',2),LazyList.from("ccc"))); print("✅")
assert(encodeHead(LazyList.from("ccc")) == (('c',3),LazyList())); print("✅")
print("|")
assert(encodeHead(LazyList.iterate('c')(c => if (c < 'z') (c+1).toChar else 'a'))._1 == ('c',1)); print("✅")
assert(encodeHead(LazyList.iterate('c')(c => if (c < 'z') (c+1).toChar else 'a'))._2.take(30) == LazyList.from("defghijklmnopqrstuvwxyzabcdefg")); print("✅")

// %% [markdown]
// **b)** Definieren Sie die Funktion `encode(cs)`, die aus einem Zeichenstrom `cs` mittels Bedarfsauswertung und `encodeHead(cs)` einen Strom codierter Tupel erstellt. **Beispiel:**
// `encode("aaabbccc".toStream).take(3).toList == List((a,3),(b,2),(c,3))`
// **Tipp:** Verwenden Sie die Methode `isEmpty` in `Stream`.

// %%
def encode: LazyList[Char] => LazyList[(Char, Int)] =
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(encode(LazyList.from("aaabbccc")).take(3).toList == List(('a',3),('b',2),('c',3))); print("✅")
print("|")
assert(encode(LazyList.from("bbccc")) == List(('b',2),('c',3))); print("✅")
assert(encode(LazyList.from("ccc")) == List(('c',3))); print("✅")
assert(encode(LazyList()) == Nil); print("✅")
print("|")
assert(encode(LazyList.from((for (c <- 'a' to 'z') yield List.fill(c-'a'+3)(c)).flatten)
              .concat(LazyList.iterate('c')(c => if (c < 'z') (c+1).toChar else 'a'))).take(8)
       == List(('a',3),('b',4),('c',5),('d',6),('e',7),('f',8),('g',9),('h',10))); print("✅")

// %% [markdown]
// **c)** Definieren Sie die Funktion `decode(ts)`, die eine Liste codierter Tupel `ts` decodiert. Verwenden Sie **<u>unbedingt</u>** `foldRight[B](z: B)(f: (A, B) => B): B` aus `List[A]`.
// **Beispiel:** `decode(List(('a',3),('b',2),('c',3))) == List(a,a,a,b,b,c,c,c)`
// **Tipp:** `List.fill(k)(c)` erstellt eine Liste bestehend aus `k` mal dem Zeichen `c`.

// %%
def decode: List[(Char, Int)] => List[Char] =
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(decode(List(('a',3),('b',2),('c',3))) == List('a','a','a','b','b','c','c','c')); print("✅")
print("|")
assert(decode(List(('b',2),('c',3))) == List('b','b','c','c','c')); print("✅")
assert(decode(List(('c',3))) == List('c','c','c')); print("✅")
assert(decode(Nil) == Nil); print("✅")
print("|")
assert(decode(List(('a',3),('b',4),('c',5),('d',6),('e',7),('f',8),('g',9),('h',10)))
       == (for (c <- 'a' to 'h') yield List.fill(c-'a'+3)(c)).flatten.toList); print("✅")
