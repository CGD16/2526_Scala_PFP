// %% [markdown]
// # Aufgabe 5 (Scala: LCA)

// %% [markdown]
// _Verwenden Sie ausschließlich aus der Lehrveranstaltung bekannte Scala-Konstrukte, dabei sind `var` und seiteneffektbehaftete Methoden/Klassen/Objekte strikt untersagt._

// %% [markdown]
// In dieser Aufgabe soll das Lowest-Common-Ancestor-Problem für Bäume gelöst werden. Jeder Knoten (`Node`) enthält dabei einen garantiert einzigartigen Namen und, solange es sich um keinen Wurzelknoten handelt, eine Referenz auf seinen direkten Vorgänger.

// %%
case class Node(name : String, pred : Option[Node])
val a = Node("A",None)
val b = Node("B",Some(a))
val c = Node("C",Some(b))
val d = Node("D",Some(b))
val e = Node("E",Some(d))
val f = Node("F",None)

// %% [markdown]
// <img src="lib/2022_08_09_klausur_p09_LCA.png" title="Tree Example for LCA" style="width: 125px;"/>

// %% [markdown]
// **a)** Vervollständigen Sie die Funktion `ancestors`, so dass ihre Signatur zu den Beispielen passt. Sie soll für einen gegebenen Knoten die Liste der Namen aller seiner Vorgänger sowie des Knotens selbst zurückliefern. Achten Sie darauf, dass Sie dabei die Reihenfolge von der Wurzel zum Knoten einhalten. Sie dürfen davon ausgehen, dass die Struktur frei von Zyklen ist.
// ```scala
//   ancestors(d) = List("A", "B", "D")
//   ancestors(f) = List("F")
// ```

// %%
def ancestors : /*** IHR CODE HIER ***/ {
   case /*** IHR CODE HIER ***/
   case /*** IHR CODE HIER ***/
}

// %%
// Beispiel und Schnelltest:
assert(ancestors(d) == List("A", "B", "D")); print("✅")
assert(ancestors(f) == List("F")); print("✅")
//
assert(ancestors(a) == List("A")); print("✅")
assert(ancestors(b) == List("A", "B")); print("✅")
assert(ancestors(c) == List("A", "B", "C")); print("✅")
assert(ancestors(e) == List("A", "B", "D", "E")); print("✅")

// %% [markdown]
// **b)** Vervollständigen Sie nun die Funktion `lastMatch`. Sie erhält zwei Listen von `String`s. Stimmt der Anfang beider Listen überein, soll eine `Option` mit dem **letzten** übereinstimmenden `String` zurückgegeben werden, ansonsten `None`.
// ```scala
//   lastMatch(List("A","B","C"),List("A","B","D")) = Some("B")
// ```

// %%
def lastMatch : /*** IHR CODE HIER ***/ {
   case /*** IHR CODE HIER ***/
}

// %%
// Beispiel und Schnelltest:
assert(lastMatch(List("A","B","C"), List("A","B","D")) == Some("B")); print("✅")
print("|")
assert(lastMatch(Nil, Nil) == None); print("✅")
assert(lastMatch(Nil, List("A")) == None); print("✅")
assert(lastMatch(List("A"), Nil) == None); print("✅")
assert(lastMatch(Nil, List("A","B","C")) == None); print("✅")
assert(lastMatch(List("A","B","C"), Nil) == None); print("✅")
print("|")
assert(lastMatch(List("A"), List("A")) == Some("A")); print("✅")
assert(lastMatch(List("X"), List("Y")) == None); print("✅")
print("|")
assert(lastMatch(List("A","B"), List("A","B")) == Some("B")); print("✅")
assert(lastMatch(List("A","X"), List("A","Y")) == Some("A")); print("✅")
assert(lastMatch(List("X","B"), List("Y","B")) == None); print("✅")
print("|")
assert(lastMatch(List("A","B","C"), List("A","B","C")) == Some("C")); print("✅")
assert(lastMatch(List("A","B","X"), List("A","B","Y")) == Some("B")); print("✅")
assert(lastMatch(List("A","X","C"), List("A","Y","C")) == Some("A")); print("✅")
assert(lastMatch(List("X","B","C"), List("Y","B","C")) == None); print("✅")

// %% [markdown]
// **c)** Ergänzen Sie schließlich die Funktion `lca`, die den Namen des letzten gemeinsamen Vorgängers `p` zweier Knoten als `Some(p)` zurückliefert, oder `None`, falls diese Knoten nicht zum selben Baum gehören.
// ```scala
//   lca(a,b) = Some("A")   lca(e,c) = Some("B")   lca(e,f) = None
// ```

// %%
def lca : /*** IHR CODE HIER ***/
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(lca(a,b) == Some("A")); print("✅")
assert(lca(e,c) == Some("B")); print("✅")
assert(lca(e,f) == None); print("✅")
print("|")
assert(lca(a,a) == Some("A")); print("✅")
assert(lca(a,c) == Some("A")); print("✅")
assert(lca(a,d) == Some("A")); print("✅")
assert(lca(a,e) == Some("A")); print("✅")
assert(lca(a,f) == None); print("✅")
print("|")
assert(lca(b,a) == Some("A")); print("✅")
assert(lca(b,b) == Some("B")); print("✅")
assert(lca(b,c) == Some("B")); print("✅")
assert(lca(b,d) == Some("B")); print("✅")
assert(lca(b,e) == Some("B")); print("✅")
assert(lca(b,f) == None); print("✅")
print("|")
assert(lca(c,a) == Some("A")); print("✅")
assert(lca(c,b) == Some("B")); print("✅")
assert(lca(c,c) == Some("C")); print("✅")
assert(lca(c,d) == Some("B")); print("✅")
assert(lca(c,e) == Some("B")); print("✅")
assert(lca(c,f) == None); print("✅")
print("|")
assert(lca(d,a) == Some("A")); print("✅")
assert(lca(d,b) == Some("B")); print("✅")
assert(lca(d,c) == Some("B")); print("✅")
assert(lca(d,d) == Some("D")); print("✅")
assert(lca(d,e) == Some("D")); print("✅")
assert(lca(d,f) == None); print("✅")
print("|")
assert(lca(e,a) == Some("A")); print("✅")
assert(lca(e,b) == Some("B")); print("✅")
assert(lca(e,d) == Some("D")); print("✅")
assert(lca(e,e) == Some("E")); print("✅")
print("|")
assert(lca(f,a) == None); print("✅")
assert(lca(f,b) == None); print("✅")
assert(lca(f,c) == None); print("✅")
assert(lca(f,d) == None); print("✅")
assert(lca(f,e) == None); print("✅")
assert(lca(f,f) == Some("F")); print("✅")
