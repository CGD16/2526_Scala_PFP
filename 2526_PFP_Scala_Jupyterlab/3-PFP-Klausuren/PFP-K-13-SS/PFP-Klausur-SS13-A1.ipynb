// %% [markdown]
// # Aufgabe 1 (Wissensfragen)

// %% [markdown]
// Bei den folgenden Teilaufgaben werden richtige Antworten positiv, falsche entsprechend negativ gewertet. Unbearbeitete Teilaufgaben werden weder positiv noch negativ bewertet. Die Aufgabe wird insgesamt mit mindestens $0$ Punkten bewertet.
// **Hinweis:** In einem Aufgabenteil kann mehr als eine Antwort korrekt sein.

// %% [markdown]
// **h)** Die Funktion `def f: ((Int, Int)) => Int` kann in der Form `f(5)(6)` aufgerufen werden.

// %%
// Führen Sie diese Zelle aus, falls die Multiple-Choice-Kästchen deaktiviert sind.
kernel.publish.html("""
<p><input type="checkbox" id="MCA_G" onclick="grade_G()">
<label for="MCA_G">
    richtig
</label>
&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
<input type="checkbox" id="MCB_G" onclick="grade_G()">
<label for="MCB_G">
    falsch
</label></p>

<div id="result_G" class="alert alert-block alert-success" style="display:none">Für Ihre Antwort würden Sie 0 von 1 Punkten erhalten.</div>

<script>
function grade_G() {
   var mcaX = document.getElementById("MCA_G").checked;
   var mcbX = document.getElementById("MCB_G").checked;
   var points = 0;
   var mX = 0; var wX = 0; // missing X, wrong X
   var mXmsg = ""; var wXmsg = "";
   if (!mcaX & mcbX){ points = 1; }
   if (mcaX){ wX += +1; } else {           }
   if (mcbX){           } else { mX += +1; }
   if (mX > 0) { mXmsg = " Sie haben " + mX + " RICHTIGE Antwort(en) NICHT angekreuzt."; }
   if (wX > 0) { wXmsg = " Sie haben " + wX + " FALSCHE Antwort(en) angekreuzt."; }
   document.getElementById("result_G").textContent = "Für Ihre Antwort würden Sie " + points + " von 1 Punkten erhalten." + mXmsg + wXmsg;
   document.getElementById("result_G").style.display = "block";
}
</script>
""")
// Out:
// <p><input type="checkbox" id="MCA_G" onclick="grade_G()">
// <label for="MCA_G">
//     richtig
// </label>
// &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
// <input type="checkbox" id="MCB_G" onclick="grade_G()">
// <label for="MCB_G">
//     falsch
// </label></p>
//
// <div id="result_G" class="alert alert-block alert-success" style="display:none">Für Ihre Antwort würden Sie 0 von 1 Punkten erhalten.</div>
//
// <script>
// function grade_G() {
//    var mcaX = document.getElementById("MCA_G").checked;
//    var mcbX = document.getElementById("MCB_G").checked;
//    var points = 0;
//    var mX = 0; var wX = 0; // missing X, wrong X
//    var mXmsg = ""; var wXmsg = "";
//    if (!mcaX & mcbX){ points = 1; }
//    if (mcaX){ wX += +1; } else {           }
//    if (mcbX){           } else { mX += +1; }
//    if (mX > 0) { mXmsg = " Sie haben " + mX + " RICHTIGE Antwort(en) NICHT angekreuzt."; }
//    if (wX > 0) { wXmsg = " Sie haben " + wX + " FALSCHE Antwort(en) angekreuzt."; }
// ...

// %% [markdown]
// ---
// _Alternative Antwortmöglichkeit, falls Multiple-Choice oben nicht funktioniert:_

// %% [markdown]
// **h)** Die Funktion `def f: ((Int, Int)) => Int` kann in der Form `f(5)(6)` aufgerufen werden.

// %% [markdown]
// <p style="white-space:nowrap">
// <b>1</b> - richtig
// &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
// <b>2</b> - falsch
// </p>

// %% [markdown]
// <div class="alert alert-block alert-info">
// Geben Sie die Ziffern der richtigen Aussagen in den runden Klammern ein - z.B. `List(7,5,9)` - und führen Sie anschließend beide Zellen aus:
// </div>

// %%
val studentSolutionH: List[Int] = List(  )

// %%
repl.load(scala.io.Source.fromFile(System.getProperty("user.dir") + "/lib/SolutionA1h.scala").mkString)
