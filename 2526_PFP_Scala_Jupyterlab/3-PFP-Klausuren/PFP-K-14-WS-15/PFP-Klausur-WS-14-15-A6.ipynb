// %% [markdown]
// # Aufgabe 6 (Scala - Lauflängendekodierung)

// %% [markdown]
// _Verwenden Sie ausschließlich aus der Lehrveranstaltung bekannte Scala-Konstrukte, dabei sind `var` und seiteneffektbehaftete Methoden/Klassen/Objekte strikt untersagt._

// %% [markdown]
// <div class="alert alert-block alert-danger">
// <b>WICHTIG:</b> Die <b>ursprüngliche</b> Klausur hat <b>damals</b> systembedingt <code>Stream</code> (<i>"Strom"</i>) statt <code>LazyList</code> verwendet!<br/>
// Grund für die Abweichung <b>hier</b>: <i>"type Stream in package scala is deprecated since 2.13.0: Use LazyList instead of Stream"</i><br/>
// <b>Ersetzen</b> Sie daher in der Aufgabenstellung die Begriffe <i>"Strom"</i> bzw. "<code>Stream</code>" <b>gedanklich</b> durch die <b>neuere</b> <code>LazyList</code>.
// </div>

// %% [markdown]
// Bei der folgenden Lauflängendekodierung wird ein Strom von Tupeln `(c, k)` zu einem Strom von Zeichen dekodiert. Pro Tupel wird dabei das Zeichen `c` jeweils `k`-mal wiederholt.
// **Beispiel:** `Stream(('a', 3), ('b', 4), ('c', 2))` wird dekodiert zu
// &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
// `Stream('a', 'a', 'a', 'b', 'b', 'b', 'b', 'c', 'c')`

// %% [markdown]
// **a)** Definieren Sie die Funktion `decodeTuple(t)`, die ein einzelnes Tupel `t = (c, k)` zu einem Strom von `k` Zeichen `c` dekodiert. Dies muss mittels einer Bedarfsauswertung erfolgen, die jeweils nur einzelne Zeichen verarbeitet.
// **Beispiel:** Folgende Anweisung wertet nur das erste von 4711 Zeichen aus:
// _(REPL)_&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`scala> decodeTuple(('a', 4711))`
// &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `res0: Stream[Char] = Stream(a, ?)`

// %%
def decodeTuple: ((Char, Int)) => LazyList[Char] =
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(decodeTuple(('a', 4711)) == LazyList.fill(4711)('a')); print("✅")
print("|")
assert((for (n <- 0 to 42) yield decodeTuple(('x', n)) == LazyList.fill(n)('x')).forall(b=>b)); print("✅")

// %% [markdown]
// **b)** Definieren Sie die Funktion `decode(ts)`, die einen Strom `ts` von Tupeln unter Verwendung von `decodeTuple` und mittels Bedarfsauswertung dekodiert.
// **Beispiel:** Folgende Zeile dekodiert nur 4 der 7 Zeichen:
// _(REPL)_&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`scala> decode(Stream(('a', 3), ('b', 4))).take(4).toList`
// &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`res1: List[Char] = List(a, a, a, b)`
// **Tipps:** Zwei Streams können durch `#:::` mittels Bedarfsauswertung verbunden werden.
// Die Verwendung von `.head` und `.tail` der Klasse `Stream` erleichtert die Bearbeitung.

// %%
def decode: LazyList[(Char, Int)] => LazyList[Char] =
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(decode(LazyList(('a', 3), ('b', 4))).take(4).toList == List('a', 'a', 'a', 'b')); print("✅")
print("|")
assert(decode(LazyList()) == LazyList()); print("✅")
print("|")
assert((for (x <- 0 to 42) yield decode(LazyList(('x',x))) == LazyList.fill(x)('x')).forall(b=>b)); print("✅")
print("|")
assert((for (x <- 0 to 42; y <- 0 to 42) yield decode(LazyList(('x',x), ('y',y))) == LazyList.fill(x)('x').concat(LazyList.fill(y)('y'))).forall(b=>b)); print("✅")
print("|")
assert(decode(LazyList.iterate(('a',0))({case (c,n) => if (c < 'z') ((c+1).toChar,n+1) else ('a',0)})).take(22) ==
       LazyList('b','c','c','d','d','d','e','e','e','e','f','f','f','f','f','g','g','g','g','g','g','h')); print("✅")
