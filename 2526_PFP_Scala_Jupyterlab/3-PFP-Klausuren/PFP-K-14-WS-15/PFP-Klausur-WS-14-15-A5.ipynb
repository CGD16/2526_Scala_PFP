// %% [markdown]
// # Aufgabe 5 (Scala - Listenoperationen)

// %% [markdown]
// _Verwenden Sie ausschließlich aus der Lehrveranstaltung bekannte Scala-Konstrukte, dabei sind `var` und seiteneffektbehaftete Methoden/Klassen/Objekte strikt untersagt._

// %% [markdown]
// <div class="alert alert-block alert-danger">
// <b>WICHTIG: Die folgende Zelle (<tt>import $ivy...</tt>) muss unbedingt <i>vor allen anderen</i> ausgeführt werden!</b>
// </div>

// %%
import $ivy.`org.scala-lang.modules::scala-parallel-collections:1.0.4`
import scala.collection.parallel.CollectionConverters._
import scala.collection.parallel.immutable._

// %% [markdown]
// **a)** Geben Sie die **<u>rekursive</u>** Funktion `flatten(ts)` an, die eine Liste `ts` von Tupeln der Form `(Char, Char)` in eine Liste der Zeichen aus `ts` umwandelt. Dabei sollen Reihenfolge und Anzahl der Zeichen entsprechend ihrem Auftreten in `ts` erhalten bleiben.
// **Beispiel:** `scala> flatten(List(('a', 'b'), ('a', 'c')))`
// _(REPL)_&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `res0: List[Char] = List(a, b, a, c)`

// %%
def flatten: List[(Char, Char)] => List[Char] =
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(flatten(List(('a', 'b'), ('a', 'c'))) == List('a','b', 'a', 'c')); print("✅")
print("|")
assert(flatten(Nil) == Nil); print("✅")
assert(flatten(List(('x','y'))) == List('x','y')); print("✅")
assert(flatten(List(('a','b'), ('c','d'), ('e','f'))) == List('a','b','c','d','e','f')); print("✅")

// %% [markdown]
// **b)** Geben Sie die **<u>parallel</u>** arbeitende Version `countPar(cs)` von `count(cs)` an. Diese ermittelt zu jedem Zeichen `c` in `cs` ein Tupel `(c, n)`, wobei `n` angibt, wie oft `c` in `cs` vorkommt.
// **Beispiel:** `scala> count(List('a', 'b', 'a', 'c'))`
// _(REPL)_&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `res1: List[(Char, Int)] = List((a,2), (b,1), (a,2), (c,1))`
// ```scala
// def count: List[Char] => List[(Char, Int)] = cs =>
//    for(c <- cs) yield (c, cs.filter(_ == c).size)
// ```

// %%
def countPar: List[Char] => List[(Char, Int)] = cs =>
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(countPar(List('a', 'b', 'a', 'c')) == List(('a',2), ('b',1), ('a',2), ('c',1))); print("✅")
print("|")
assert(countPar(Nil) == Nil); print("✅")
print("|")
assert(countPar(List('a')) == List(('a',1))); print("✅")
print("|")
assert(countPar(List('a', 'a')) == List(('a',2), ('a',2))); print("✅")
assert(countPar(List('a', 'b')) == List(('a',1), ('b',1))); print("✅")
print("|")
assert(countPar(List('a', 'a', 'a')) == List(('a',3), ('a',3), ('a',3))); print("✅")
assert(countPar(List('a', 'a', 'b')) == List(('a',2), ('a',2), ('b',1))); print("✅")
assert(countPar(List('a', 'b', 'a')) == List(('a',2), ('b',1), ('a',2))); print("✅")
assert(countPar(List('a', 'b', 'b')) == List(('a',1), ('b',2), ('b',2))); print("✅")
assert(countPar(List('a', 'b', 'c')) == List(('a',1), ('b',1), ('c',1))); print("✅")

// %% [markdown]
// **c)** Geben Sie die Funktion `distinct(xs)` an, die aus der Liste `xs` alle Duplikate entfernt. Die Reihenfolge der Elemente in der Ergebnisliste ist irrelevant.
// Verwenden Sie **<u>unbedingt</u>** `foldLeft[B](z: B)(f: (B, A) => B): B` aus `List[A]`.
// **Beispiel:** `scala> distinct(List(('a',2), ('b',1), ('a',2), ('c',1)))`
// _(REPL)_&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; `res2: List[(Char, Int)] = List((c,1), (b,1), (a,2))`
// **Tipp:** Sie dürfen `contains(elem: Any): Boolean` aus der Klasse `List` verwenden.

// %%
def distinct: List[(Char, Int)] => List[(Char, Int)] =
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
{
def check: List[(Char, Int)] => List[(Char, Int)] => Boolean = expected => actual =>
   actual.distinct == actual &&
   expected.length == expected.length &&
   (for (p <- expected) yield actual.contains(p)).forall(b=>b) &&
   (for (p <- actual) yield expected.contains(p)).forall(b=>b)
assert(check(List(('c',1), ('b',1), ('a',2))) (distinct(List(('a',2), ('b',1), ('a',2), ('c',1))))); print("✅")
print("|")
assert(distinct(Nil) == Nil); print("✅")
print("|")
assert(distinct(List(('a',1))) == List(('a',1))); print("✅")
print("|")
assert(distinct(List(('a',2), ('a',2))) == List(('a',2))); print("✅")
assert(check(List(('a',1), ('a',2))) (distinct(List(('a',1), ('a',2))))); print("✅")
assert(check(List(('a',1), ('b',1))) (distinct(List(('a',1), ('b',1))))); print("✅")
print("|")
assert(distinct(List(('a',3), ('a',3), ('a',3))) == List(('a',3))); print("✅")
assert(check(List(('a',2), ('b',1))) (distinct(List(('a',2), ('a',2), ('b',1))))); print("✅")
assert(check(List(('a',2), ('b',1))) (distinct(List(('a',2), ('b',1), ('a',2))))); print("✅")
assert(check(List(('a',1), ('b',2))) (distinct(List(('a',1), ('b',2), ('b',2))))); print("✅")
assert(check(List(('a',1), ('b',1), ('c',1))) (distinct(List(('a',1), ('b',1), ('c',1))))); print("✅")
assert(check(List(('a',2), ('b',1), ('a',3))) (distinct(List(('a',2), ('b',1), ('a',3))))); print("✅")
}
