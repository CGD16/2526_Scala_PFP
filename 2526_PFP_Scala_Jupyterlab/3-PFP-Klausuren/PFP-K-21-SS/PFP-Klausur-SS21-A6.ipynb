// %% [markdown]
// # Aufgabe 6 (Scala: Queens)

// %% [markdown]
// _Verwenden Sie ausschließlich aus der Lehrveranstaltung bekannte Scala-Konstrukte, dabei sind `var` und seiteneffektbehaftete Methoden/Klassen/Objekte strikt untersagt._

// %% [markdown]
// Gegeben seien folgende Typen und Funktionen:

// %%
type Col = Char // chess board column index
type Row = Int // chess board row index
val cols = List('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h')
val rows = List(1, 2, 3, 4, 5, 6, 7, 8)
type Field = (Col, Row) // field within chess board
def sameColumn: (Field, Field) => Boolean = (a, b) => a._1 == b._1
def sameRow: (Field, Field) => Boolean = (a, b) => a._2 == b._2
def sameDiagonal: (Field, Field) => Boolean =
   (a, b) => (a._1 - b._1).abs == (a._2 - b._2).abs
def beats: Field => Field => Boolean =
   a => b => sameColumn(a, b) || sameRow(a, b) || sameDiagonal(a, b)

// %% [markdown]
// Das Damenproblem besteht darin, acht Damen auf einem normalen Schachbrett $(8 \times 8)$ so zu platzieren, dass keine Dame die andere schlägt (`beats`).

// %% [markdown]
// **a)** Ergänzen Sie die Funktion `getFreeRows`: Sie bekommt die Liste der von Damen besetzten Felder und soll die Liste der Damen-freien Zeilen zurückgeben.

// %%
def getFreeRows: List[Field] => List[Row] = qs =>
   rows./*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(getFreeRows(Nil) == rows); print("✅")
assert(getFreeRows(List(('a',1))) == List(2, 3, 4, 5, 6, 7, 8)); print("✅")
assert(getFreeRows(List(('b',2))) == List(1, 3, 4, 5, 6, 7, 8)); print("✅")
assert(getFreeRows(List(('g',7))) == List(1, 2, 3, 4, 5, 6, 8)); print("✅")
assert(getFreeRows(List(('h',8))) == List(1, 2, 3, 4, 5, 6, 7)); print("✅")

// %% [markdown]
// **b)** Ergänzen Sie folgende Funktion: Sie bekommt die Liste der von Damen besetzten Felder sowie eine noch freie Zeile und soll alle Felder dieser Zeile zurückgeben, die noch nicht von Damen _geschlagen_ werden.

// %%
def getFreeFieldsInRow: List[Field] => Row => List[Field] = qs => row =>
   for ( /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(getFreeFieldsInRow(Nil)(1) == (for(c <- cols) yield (c,1))); print("✅")
assert(getFreeFieldsInRow(Nil)(2) == (for(c <- cols) yield (c,2))); print("✅")
assert(getFreeFieldsInRow(Nil)(7) == (for(c <- cols) yield (c,7))); print("✅")
assert(getFreeFieldsInRow(Nil)(8) == (for(c <- cols) yield (c,8))); print("✅")
print("|")
assert(getFreeFieldsInRow(List(('a',1)))(2) == (for(c <- List('c', 'd', 'e', 'f', 'g', 'h')) yield (c,2))); print("✅")
assert(getFreeFieldsInRow(List(('a',1)))(8) == (for(c <- List('b', 'c', 'd', 'e', 'f', 'g')) yield (c,8))); print("✅")
assert(getFreeFieldsInRow(List(('h',1)))(2) == (for(c <- List('a', 'b', 'c', 'd', 'e', 'f')) yield (c,2))); print("✅")
print("|")
assert(getFreeFieldsInRow(List(('d',5)))(1) == (for(c <- List('a', 'b', 'c', 'e', 'f', 'g')) yield (c,1))); print("✅")
assert(getFreeFieldsInRow(List(('d',5)))(2) == (for(c <- List('b', 'c', 'e', 'f', 'h')) yield (c,2))); print("✅")
assert(getFreeFieldsInRow(List(('d',5)))(3) == (for(c <- List('a', 'c', 'e', 'g', 'h')) yield (c,3))); print("✅")
assert(getFreeFieldsInRow(List(('d',5)))(4) == (for(c <- List('a', 'b', 'f', 'g', 'h')) yield (c,4))); print("✅")
print("|")
assert(getFreeFieldsInRow(List(('a',1), ('c',2)))(3) == (for(c <- List('e', 'f', 'g', 'h')) yield (c,3))); print("✅")
print("|")
assert(getFreeFieldsInRow(List(('g',5), ('b',3)))(1) == (for(c <- List('a', 'e', 'f', 'h')) yield (c,1))); print("✅")
assert(getFreeFieldsInRow(List(('g',5), ('b',3)))(2) == (for(c <- List('e', 'f', 'h')) yield (c,2))); print("✅")
assert(getFreeFieldsInRow(List(('g',5), ('b',3)))(4) == (for(c <- List('d', 'e')) yield (c,4))); print("✅")
assert(getFreeFieldsInRow(List(('g',5), ('b',3)))(6) == (for(c <- List('a', 'c', 'd')) yield (c,6))); print("✅")
assert(getFreeFieldsInRow(List(('g',5), ('b',3)))(7) == (for(c <- List('a', 'c', 'd', 'h')) yield (c,7))); print("✅")
assert(getFreeFieldsInRow(List(('g',5), ('b',3)))(8) == (for(c <- List('a', 'c', 'e', 'f', 'h')) yield (c,8))); print("✅")

// %% [markdown]
// **c)** Ergänzen Sie die Funktion `solve`: Sie bekommt die Liste der bereits von Damen belegten Felder und soll sie zu einer beliebigen Lösung des Damenproblems ergänzen. Sie dürfen hier annehmen, dass es garantiert mindestens eine Lösung gibt.

// %%
def solve: List[Field] => List[Field] = queens => {
   /*** IHR CODE HIER ***/ match {
      case /*** IHR CODE HIER ***/ => /*** IHR CODE HIER ***/
      case /*** IHR CODE HIER ***/ => /*** IHR CODE HIER ***/.foldLeft(
         /*** IHR CODE HIER ***/
   }
}

// %%
// Beispiel und Schnelltest:
{
val wikiSol = List(('h',1),('d',2),('a',3),('c',4),('f',5),('b',6),('g',7),('e',8))
def swap: (List[Field], Field, Field) => List[Field] = {
    case (sol,(xc,xr),(yc,yr)) => sol.map({case (c,r) => if (c == xc) (xc,yr) else if (c == yc) (yc,xr) else (c,r)})
}
def check: List[Field] => List[Field] => Boolean = expected => actual =>
   expected.length == actual.length &&
   (for(f <- expected) yield actual.contains(f)).forall(w=>w) &&
   (for(f <- actual) yield expected.contains(f)).forall(w=>w)
def checkOne: Int => Boolean = xr =>
    check(wikiSol)(solve(wikiSol.filter({case (c,r) => r!=xr})))
def checkTwo: (Int,Int) => Boolean = (xr,yr) =>
    check(wikiSol)(solve(wikiSol.filter({case (c,r) => r!=xr && r!=yr}))) ||
    check(swap(wikiSol,wikiSol(xr-1),wikiSol(yr-1))) (solve(wikiSol.filter({case (c,r) => r!=xr && r!=yr})))

assert(check(wikiSol) (solve(wikiSol))); print("✅")
print("|")
// remove one row at a time from known solution and let student code find it:
assert((for(xr <- 1 to 8) yield {print("."); checkOne(xr)}).forall(w=>w)); print("✅")
print("|")
// remove two rows at a time from known solution and let student code find both
assert((for(xr <- 1 to 8; yr <- 1 to 8) yield {print("."); checkTwo(xr,yr)}).forall(w=>w)); print("✅")
}
