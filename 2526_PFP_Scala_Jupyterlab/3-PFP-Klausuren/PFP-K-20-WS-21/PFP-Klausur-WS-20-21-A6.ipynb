// %% [markdown]
// # Aufgabe 6 (Scala: Picknick)

// %% [markdown]
// _Verwenden Sie ausschließlich aus der Lehrveranstaltung bekannte Scala-Konstrukte, dabei sind `var` und seiteneffektbehaftete Methoden/Klassen/Objekte strikt untersagt._

// %% [markdown]
// Nach der Pandemie möchte Alice mit ihrem Freundeskreis ein Picknick veranstalten. Dazu hat sie eine Liste der Speisen erstellt, die die eingeladenen Personen mögen, z. B.:

// %%
type Food = String
val liked = List( List("Brot", "Paprika"),   List("Wurst", "Brot"),
                  List("Paprika", "Apfel") )

// %% [markdown]
// Gesucht ist nun die günstigste Auswahl an Speisen für _*beliebige*_ Eingabelisten, sodass jede Person eine gemochte Speise essen kann. Die Kosten liefert eine Kostenfunktion, z. B.:
// ```scala
// def cost: Food => Int = {
//    case "Apfel" | "Wurst" => 3
//    case default           => 2
// }
// ```

// %% [markdown]
// **a)** Ergänzen Sie die Funktion `removeAll(e, ls)`, die aus einer Liste von Listen von Speisen `ls` diejenigen Listen entfernen soll, die die Speise `e` enthalten. Beispiel:
// ```scala
//   removeAll("Brot", liked) == List(List("Paprika", "Apfel"))
// ```

// %%
def removeAll: (Food, List[List[Food]]) => List[List[Food]]
   = (e, ls) => ls./*** IHR CODE HIER ***/ ( /*** IHR CODE HIER ***/ )

// %%
// Beispiel und Schnelltest:
assert(removeAll("Brot", liked) == List(List("Paprika", "Apfel"))); print("✅")
print("|")
assert(removeAll("Wurst", Nil) == Nil); print("✅")
assert(removeAll("Wurst", List(Nil)) == List(Nil)); print("✅")
print("|")
assert(removeAll("Brot", List(List("Brot"))) == Nil); print("✅")
assert(removeAll("Wurst", List(List("Brot"))) == List(List("Brot"))); print("✅")
assert(removeAll("Brot", List(List("Wurst"))) == List(List("Wurst"))); print("✅")
print("|")
assert(removeAll("Brot", List(List("Brot"),List("Brot"))) == Nil); print("✅")
assert(removeAll("Wurst", List(List("Brot"),List("Wurst"))) == List(List("Brot"))); print("✅")
assert(removeAll("Wurst", List(List("Wurst"),List("Brot"))) == List(List("Brot"))); print("✅")
assert(removeAll("Brot", List(List("Wurst"),List("Wurst"))) == List(List("Wurst"),List("Wurst"))); print("✅")
print("|")
assert(removeAll("Brot", List(List("Wurst","Apfel","Brot"),List("Tomate","Apfel"),List("Wurst","Brot","Apfel"),List("Paprika","Wurst"),List("Brot","Wurst","Apfel"))) == List(List("Tomate","Apfel"),List("Paprika","Wurst"))); print("✅")
print("|")
assert(removeAll("Fisch", liked) == liked); print("✅")

// %% [markdown]
// **b)** Vervollständigen Sie die Funktion `minResult(cf, ls)`, die aus einer Liste von Listen von Speisen `ls` diejenige zurückgibt, deren Summe der durch die Kostenfunktion `cf` gegebenen Kosten am niedrigsten ist, oder `Nil`, falls `ls` leer ist. Beispiel:
// ```scala
//   minResult(cost, liked) == List("Brot", "Paprika"))
// ```

// %%
def minResult: (Food => Int, List[List[Food]]) => List[Food]
   = (cf, ls) => /*** IHR CODE HIER ***/.foldLeft(/*** IHR CODE HIER ***/)(
      (r, e) => {
         /*** IHR CODE HIER ***/
      })

// %%
// Beispiel und Schnelltest:
{
def costFun: Food => Int = {
   case "Apfel" => 11
   case "Wurst" => 7
   case "Brot" => 5
   case "Paprika" => 3
}

assert(minResult(costFun,liked) == List("Brot", "Paprika")); print("✅")
print("|")
assert(minResult(costFun,Nil) == Nil); print("✅")
assert(minResult(costFun,List(Nil)) == Nil); print("✅")
print("|")
assert(minResult(costFun,List(List("Brot"))) == List("Brot")); print("✅")
assert(minResult(costFun,List(List("Wurst"),List("Paprika"))) == List("Paprika")); print("✅")
assert(minResult(costFun,List(List("Paprika"),List("Wurst"))) == List("Paprika")); print("✅")
print("|")
assert(minResult(costFun,List(List("Wurst"),List("Paprika","Paprika"))) == List("Paprika","Paprika")); print("✅")
assert(minResult(costFun,List(List("Wurst","Paprika"),List("Apfel"))) == List("Wurst","Paprika")); print("✅")
print("|")
assert(minResult(costFun,List(List("Wurst","Brot"),List("Apfel","Paprika"),List("Paprika","Wurst"))) == List("Paprika","Wurst")); print("✅")
}

// %% [markdown]
// **c)** Die Funktion `best(cf, ls)` sucht die günstigste Auswahl von Speisen gemäß Kostenfunktion `cf`, sodass das Ergebnis mindestens eine Speise aus jeder Liste aus `ls` enthält.<br/>
// Beispiel:<br/>
// `best(cost, liked) == List("Paprika", "Brot")`<br/>
// Das heißt, dass mit den Speisen `"Paprika"` und `"Brot"` alle Freunde zufrieden sind.<br/>
// Implementieren Sie dazu die Hilfsfunktion `helper(ps)(fs)`, die eine Teillösung `ps` sowie die Liste der noch unerfüllten Speisewünsche `fs` erhält, rekursiv alle Möglichkeiten betrachtet und mit `minResult` die günstigste auswählt.<br/>
// Nehmen Sie an, dass `fs` keine leeren Listen und keine Listen mit in `ps` vorhandenen Speisen enthält. Garantieren Sie letzteres bei Ihren rekursiven Aufrufen mittels `removeAll`.

// %%
def best: (Food => Int, List[List[Food]]) => List[Food] = (cf, fs) => {

   def helper: (List[Food], List[List[Food]]) => List[Food]
      = (ps, fs) => fs match {
      // keine offenen Vorlieben mehr -> Einkaufsliste fertig
      case Nil     => Nil

      // letzte Liste h: h sind unberücksichtigte Vorlieben der letzten
      // Person -> nehme Speise in Ergebnis auf, die die Kosten minimiert
      case h::Nil  => minResult(cf, /*** IHR CODE HIER ***/ )

      // wähle nacheinander Speisen (Food) aus h und führe Rekursion durch
      case h::ts   => minResult(cf, /*** IHR CODE HIER ***/ )
   }

   helper(Nil, fs)
}

// %%
// Beispiel und Schnelltest:
{
def costFun: Food => Int = {
   case "Apfel" => 11
   case "Wurst" => 7
   case "Brot" => 5
   case "Paprika" => 3
}

def check: List[Food] => List[Food] => Boolean = expected => actual =>
   expected.length == actual.length &&
   (for(f <- expected) yield actual.contains(f)).forall(w=>w) &&
   (for(f <- actual) yield expected.contains(f)).forall(w=>w)

assert(check(List("Paprika", "Brot")) (best(costFun, liked))); print("✅")
print("|")
assert(best(costFun, Nil) == Nil); print("✅")
print("|")
assert(check(List("Wurst")) (best(costFun, List(List("Wurst"))))); print("✅")
assert(check(List("Brot")) (best(costFun, List(List("Wurst","Brot"))))); print("✅")
assert(check(List("Wurst")) (best(costFun, List(List("Wurst","Wurst"))))); print("✅")
assert(check(List("Brot")) (best(costFun, List(List("Brot","Wurst"))))); print("✅")
print("|")
assert(check(List("Wurst","Brot")) (best(costFun, List(List("Wurst"),List("Brot"))))); print("✅")
assert(check(List("Wurst")) (best(costFun, List(List("Wurst"),List("Wurst"))))); print("✅")
assert(check(List("Wurst","Brot")) (best(costFun, List(List("Brot"),List("Wurst"))))); print("✅")
print("|")
assert(check(List("Paprika")) (best(costFun, List(List("Paprika","Apfel"),List("Apfel","Paprika"))))); print("✅")
assert(check(List("Paprika")) (best(costFun, List(List("Apfel","Paprika"),List("Paprika","Apfel"))))); print("✅")
assert(check(List("Paprika")) (best(costFun, List(List("Apfel","Paprika"),List("Paprika","Brot"))))); print("✅")
assert(check(List("Paprika", "Brot")) (best(costFun, List(List("Apfel","Paprika"),List("Wurst","Brot"))))); print("✅")
print("|")
assert(check(List("Paprika")) (best(costFun, List(List("Apfel","Paprika"),List("Paprika","Wurst"),List("Brot","Paprika"))))); print("✅")
assert(check(List("Apfel")) (best(costFun, List(List("Apfel","Paprika"),List("Wurst","Apfel"),List("Apfel","Brot"))))); print("✅")
assert(check(List("Brot","Paprika")) (best(costFun, List(List("Apfel","Paprika"),List("Wurst","Brot","Apfel"),List("Apfel","Brot"))))); print("✅")
}
