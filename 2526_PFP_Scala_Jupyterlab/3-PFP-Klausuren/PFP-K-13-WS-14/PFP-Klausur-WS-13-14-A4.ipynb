// %% [markdown]
// # Aufgabe 4 (Scala - Teilersummen)

// %% [markdown]
// _Verwenden Sie ausschließlich aus der Lehrveranstaltung bekannte Scala-Konstrukte, dabei sind `var` und seiteneffektbehaftete Methoden/Klassen/Objekte strikt untersagt._

// %% [markdown]
// <div class="alert alert-block alert-danger">
// <b>WICHTIG:</b> Die <b>ursprüngliche</b> Klausur hat <b>damals</b> systembedingt <code>Stream</code> (<i>"Strom"</i>) statt <code>LazyList</code> verwendet!<br/>
// Grund für die Abweichung <b>hier</b>: <i>"type Stream in package scala is deprecated since 2.13.0: Use LazyList instead of Stream"</i><br/>
// <b>Ersetzen</b> Sie daher in der Aufgabenstellung die Begriffe <i>"Strom"</i> bzw. "<code>Stream</code>" <b>gedanklich</b> durch die <b>neuere</b> <code>LazyList</code>.
// </div>

// %% [markdown]
// Die Teilersumme $fs(n)$ der natürlichen Zahl $n$ sei die Summe ihrer ganzzahligen Teiler ohne $n$.
// **Beispiel:**
// <table>
//     <tr style="border-bottom: 1px solid #000;">
//         <td style="text-align: center;">$n$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$4$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$5$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$6$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$7$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$8$</td>
//     </tr>
//     <tr>
//         <td style="text-align: center;">$fs(n)$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$1+2=3$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$1=1$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$1+2+3=6$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$1=1$</td>
//         <td style="border-left: 1px solid #000; text-align: center;">$1+2+4=7$</td>
//     </tr>
// </table>

// %% [markdown]
// **a)** Die Funktion `fs(n)` ($n > 0$ wird garantiert) soll wie folgt ausgedrückt werden:

// %%
def facs: Int => List[Int] /* facs(n) liefert die Teiler von n (ohne n) */ = n => List.range(1,n/2+1).filter(n%_==0)
def sum: List[Int] => Int /* sum(xs) summiert alle Zahlen in xs */ = ls => ls.sum
// def fs: Int => Int = construct(facs)(sum)

// %% [markdown]
// Geben Sie die hierfür notwendige Funktion `construct(f)(s)` **<u>inklusive</u>** Signatur an:

// %%
def construct: /*** IHR CODE HIER ***/

// %%
// Diese Zelle bitte unbedingt NACH der vorangehenden und VOR den nachfolgenden ausführen!
def fs: Int => Int = construct(facs)(sum)

// %%
// Beispiel und Schnelltest:
assert(List(fs(4),fs(5),fs(6),fs(7),fs(8)) == List(3,1,6,1,7)); print("✅")
print("|")
assert((for (n <- 2 to 26) yield fs(n)) == List(1,1,3,1,6,1,7,4,8,1,16,1,10,9,15,1,21,1,22,11,14,1,36,6,16)); print("✅")
print("|")
def ps = construct(List.range(1,_))(_.product)
assert(List(ps(1),ps(2),ps(3),ps(4),ps(5),ps(6),ps(7)) == List(1,1,2,6,24,120,720)); print("✅")

// %% [markdown]
// **b)** Die Folge $fss(n_0)$ bestehe aus den Tupeln $(n_i, fs(n_i))$ mit $i \geq 0$ und $n_{i+1} = n_i + 1$. Definieren Sie die Funktion `fss(n0)`, die die obige Folge als unendlichen `Stream` zurückgibt.
// **Beispiel:** `fss(4).take(5).toList == List((4,3), (5,1), (6,6), (7,1), (8,7))`

// %%
def fss: Int => LazyList[(Int, Int)] =
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(fss(4).take(5).toList == List((4,3), (5,1), (6,6), (7,1), (8,7))); print("✅")
print("|")
assert(fss(2).take(25).toList == List((2,1), (3,1), (4,3), (5,1), (6,6), (7,1), (8,7),
                                      (9,4), (10,8), (11,1), (12,16), (13,1), (14,10),
                                      (15,9), (16,15), (17,1), (18,21), (19,1), (20,22),
                                      (21,11), (22,14), (23,1), (24,36), (25,6), (26,16))); print("✅")

// %% [markdown]
// **c)** Geben Sie die Funktion `count(n0, m)` an, die aus den ersten `m` Elementen von `fss(n0)` die Anzahl der Tupel $(n_i, fs(n_i))$ ermittelt, für die $n_i > fs(n_i)$ gilt. Verwenden Sie **<u>unbedingt</u>** `foldLeft[B](z: B)(f: (B, A) => B): B` aus `List[A]`.
// **Beispiel:** `count(4, 5) == 4` mit $fss(4) = (4,3), (5,1),$ <del>(6,6)</del>$, (7,1), (8,7), \ldots$

// %%
def count: (Int, Int) => Int =
   /*** IHR CODE HIER ***/

// %%
// Beispiel und Schnelltest:
assert(count(4, 5) == 4); print("✅")
print("|")
assert(count(2, 25) == 20); print("✅")
